# %%
import os 
import pandas as pd
nueva_ruta = r'C:\Users\Luis\Documents\GitHub\TFM_KSCHOOL\Luis\PreModelado_TFM_Palas\Noviembre\PreModelado_Palas'
os.chdir(nueva_ruta)
print("Nueva ruta actual:", os.getcwd())

# %%
"""
df_form = pd.read_csv('df_scaled_formularios.csv')
df_palas = pd.read_csv('df_scaled_palas.csv')

df_form2 = pd.read_csv('df_scaled_formularios_2.0.csv')
df_palas2 = pd.read_csv('df_scaled_palas_2.0.csv')
# Verificar la carga
print(df_form.head())
print(df_palas.head())"""

# %%
df_form3 = pd.read_csv('df_scaled_formularios_3.0.csv')
df_palas3 = pd.read_csv('df_scaled_palas_3.0.csv')

# %%
"""import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np



# Seleccionar 200 filas aleatorias de df_form
random_rows = df_form.sample(200)

# Extraer las coordenadas X e Y de las 200 filas aleatorias
x_random = random_rows['Score_Escalar_Lesion']
y_random = random_rows['Score_Escalar_Nivel']

# Crear figura
fig = plt.figure(figsize=(20, 14))

# Crear un gráfico en 3D
ax = fig.add_subplot(111)

# Definir los valores de cada eje para el DataFrame principal (df_palas_filtrado)
x = df_palas_filtrado['score_lesion']
y = df_palas_filtrado['score_nivel']

# Crear el gráfico de dispersión 3D para df_palas_filtrado
ax.scatter(x, y, color='blue', label='Datos de Palas Filtrados')

# Crear el gráfico de dispersión 3D para los puntos adicionales
ax.scatter(x_random, y_random, color='red', s=100, label='Formulario con 200 propuestas de precios')

# Calcular los límites con buffer
x_min, x_max = x.min(), x.max()
y_min, y_max = y.min(), y.max()
buffer = 0.05  # Cambia este valor para ajustar el tamaño del margen

# Ajustar límites de los ejes con el buffer
ax.set_xlim(x_min - buffer, x_max + buffer)
ax.set_ylim(y_min - buffer, y_max + buffer)

# Añadir etiquetas a los ejes
ax.set_xlabel('Score de Lesión (Escalado)')
ax.set_ylabel('Score de Nivel (Escalado)')

# Título del gráfico
ax.set_title('Gráfico 3D de Score de Lesión, Score de Nivel y Formulario con 200 propuestas')

# Añadir leyenda para diferenciar los conjuntos de puntos
ax.legend()

# Mostrar el gráfico
plt.show()"""

# %%
"""import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import random

# Seleccionar una fila aleatoria de df_form
random_row = df_form.sample(200)


# Extraer las coordenadas X e Y de la fila aleatoria
x_random = random_row['Score_Escalar_Lesion']
y_random = random_row['Score_Escalar_Nivel']

# Valores Z fijos para los tres puntos
#z_random = [0, 1, 2]

# Crear figura
fig = plt.figure(figsize=(20, 14))

# Crear un gráfico en 2D
ax = fig.add_subplot(111)

# Definir los valores de cada eje para el DataFrame principal (df_palas)
x = df_palas['score_lesion']
y = df_palas['score_nivel']
#z = df_palas['Balance']  # Eje Z para df_palas

# Crear el gráfico de dispersión 3D para df_palas
ax.scatter(x, y, color='blue', label='Datos de Palas')

# Crear los puntos adicionales
ax.scatter([x_random], [y_random],
           color='red', s=100, label='Formularios')

# Calcular los límites con buffer
x_min, x_max = x.min(), x.max()
y_min, y_max = y.min(), y.max()
buffer = 0.01  # Cambia este valor para ajustar el tamaño del margen

# Ajustar límites de los ejes con el buffer
ax.set_xlim(x_min - buffer, x_max + buffer)
ax.set_ylim(y_min - buffer, y_max + buffer)

# Añadir etiquetas a los ejes
ax.set_xlabel('Score de Lesión (Escalado)')
ax.set_ylabel('Score de Nivel (Escalado)')

# Título del gráfico
ax.set_title('Gráfico 3D de Score de Lesión, Score de Nivel y Formulario 3 horquillas')

# Añadir leyenda para diferenciar los conjuntos de puntos
ax.legend()

# Mostrar el gráfico
plt.show()"""

# %%
"""import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import random

# Seleccionar una fila aleatoria de df_form
random_row = df_form2.sample(200)


# Extraer las coordenadas X e Y de la fila aleatoria
x_random = random_row['Score_Escalar_Lesion']
y_random = random_row['Score_Escalar_Nivel']

# Valores Z fijos para los tres puntos
#z_random = [0, 1, 2]

# Crear figura
fig = plt.figure(figsize=(20, 14))

# Crear un gráfico en 2D
ax = fig.add_subplot(111)

# Definir los valores de cada eje para el DataFrame principal (df_palas)
x = df_palas['score_lesion']
y = df_palas['score_nivel']
#z = df_palas['Balance']  # Eje Z para df_palas

# Crear el gráfico de dispersión 3D para df_palas
ax.scatter(x, y, color='blue', label='Datos de Palas')

# Crear los puntos adicionales
ax.scatter([x_random], [y_random],
           color='red', s=100, label='Formularios')

# Calcular los límites con buffer
x_min, x_max = x.min(), x.max()
y_min, y_max = y.min(), y.max()
buffer = 0.01  # Cambia este valor para ajustar el tamaño del margen

# Ajustar límites de los ejes con el buffer
ax.set_xlim(x_min - buffer, x_max + buffer)
ax.set_ylim(y_min - buffer, y_max + buffer)

# Añadir etiquetas a los ejes
ax.set_xlabel('Score de Lesión (Escalado)')
ax.set_ylabel('Score de Nivel (Escalado)')

# Título del gráfico
ax.set_title('Gráfico 3D de Score de Lesión, Score de Nivel y Formulario 3 horquillas')

# Añadir leyenda para diferenciar los conjuntos de puntos
ax.legend()

# Mostrar el gráfico
plt.show()
"""

# %%
"""import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import random

# Seleccionar una fila aleatoria de df_form
random_row = df_form2.sample(200)


# Extraer las coordenadas X e Y de la fila aleatoria
x_random = random_row['Score_Escalar_Lesion']
y_random = random_row['Score_Escalar_Nivel']

# Valores Z fijos para los tres puntos
#z_random = [0, 1, 2]

# Crear figura
fig = plt.figure(figsize=(20, 14))

# Crear un gráfico en 2D
ax = fig.add_subplot(111)

# Definir los valores de cada eje para el DataFrame principal (df_palas)
x = df_palas2['score_lesion']
y = df_palas2['score_nivel']
#z = df_palas['Balance']  # Eje Z para df_palas

# Crear el gráfico de dispersión 3D para df_palas
ax.scatter(x, y, color='blue', label='Datos de Palas')

# Crear los puntos adicionales
ax.scatter([x_random], [y_random],
           color='red', s=100, label='Formularios')

# Calcular los límites con buffer
x_min, x_max = x.min(), x.max()
y_min, y_max = y.min(), y.max()
buffer = 0.01  # Cambia este valor para ajustar el tamaño del margen

# Ajustar límites de los ejes con el buffer
ax.set_xlim(x_min - buffer, x_max + buffer)
ax.set_ylim(y_min - buffer, y_max + buffer)

# Añadir etiquetas a los ejes
ax.set_xlabel('Score de Lesión (Escalado)')
ax.set_ylabel('Score de Nivel (Escalado)')

# Título del gráfico
ax.set_title('Gráfico 3D de Score de Lesión, Score de Nivel y Formulario 3 horquillas')

# Añadir leyenda para diferenciar los conjuntos de puntos
ax.legend()

# Mostrar el gráfico
plt.show()
"""

# %%
import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import random

# Seleccionar 200 filas aleatoria de df_form
random_row = df_form3.sample(1)


# Extraer las coordenadas X e Y de la fila aleatoria
x_random = random_row['Score_Escalar_Lesion']
y_random = random_row['Score_Escalar_Nivel']

# Crear figura
fig = plt.figure(figsize=(20, 14))

# Crear un gráfico en 2D
ax = fig.add_subplot(111)

# Definir los valores de cada eje para el DataFrame principal (df_palas)
x = df_palas3['score_lesion_ajustado']
y = df_palas3['score_nivel_ajustado']
#z = df_palas['Balance']  # Eje Z para df_palas

# Crear el gráfico de dispersión 3D para df_palas
ax.scatter(x, y, color='blue', label='Datos de Palas')

# Crear los puntos adicionales
ax.scatter([x_random], [y_random],
           color='red', s=100, label='Formularios')

# Calcular los límites con buffer
x_min, x_max = x.min(), x.max()
y_min, y_max = y.min(), y.max()
buffer = 0.01  # Cambia este valor para ajustar el tamaño del margen

# Ajustar límites de los ejes con el buffer
ax.set_xlim(x_min - buffer, x_max + buffer)
ax.set_ylim(y_min - buffer, y_max + buffer)

# Añadir etiquetas a los ejes
ax.set_xlabel('Score de Lesión (Escalado)')
ax.set_ylabel('Score de Nivel (Escalado)')

# Título del gráfico
ax.set_title('Gráfico 3D de Score de Lesión, Score de Nivel y Formulario 3 horquillas')

# Añadir leyenda para diferenciar los conjuntos de puntos
ax.legend()

# Mostrar el gráfico
plt.show()

# %%
# Filtrar filas en base al sexo indicado en df_form
sexo_form = df_form3["Indique su sexo"].iloc[0]  # Supongamos que tomas el sexo de la primera fila de df_form

if sexo_form == "hombre":
    # Filtrar df_palas para incluir solo jugadores "hombre" o "mixta"
    df_palas_filtrado = df_palas3[(df_palas3["Jugador"] == "hombre") | (df_palas3["Jugador"] == "mixta")]
elif sexo_form == "mujer":
    # Filtrar df_palas para incluir solo jugadores "mujer" o "mixta"
    df_palas_filtrado = df_palas3[(df_palas3["Jugador"] == "mujer") | (df_palas3["Jugador"] == "mixta")]
else:
    # En caso de no especificar un sexo, incluir todo el DataFrame
    df_palas_filtrado = df_palas3

# %%
"""from sklearn.neighbors import NearestNeighbors
import pandas as pd
import numpy as np

# Crear los puntos de referencia con sus coordenadas X, Y
reference_points = pd.DataFrame({
    'score_lesion': [x_random] * 3,
    'score_nivel': [y_random] * 3,

})

# Preparar los datos de df_palas para aplicar kNN
# Aseguramos que 'Palas' esté en el DataFrame para poder recuperar los nombres
palas_data = df_palas[['score_lesion', 'score_nivel', 'Balance', 'Palas']].copy()

# Entrenar el modelo kNN con las columnas relevantes (sin la columna 'Palas')
knn = NearestNeighbors(n_neighbors=3)
knn.fit(palas_data[['score_lesion', 'score_nivel', 'Balance']])

# Encontrar los 3 vecinos más cercanos para cada punto de referencia
results = {}
for index, point in reference_points.iterrows():
    distances, indices = knn.kneighbors([point])
    closest_points = palas_data.iloc[indices[0]]
    results[f'Punto {point["Balance"]}'] = closest_points

# Mostrar los resultados con los nombres de las palas
for key, value in results.items():
    print(f"Vecinos más cercanos a {key}:")
    print(value[['Palas', 'score_lesion', 'score_nivel', 'Balance']], "\n")"""

# %%
"""def encontrar_vecinos_mas_cercanos_knn(df_palas, x_random, y_random, z_random, considerar_precio, precio_maximo):
    knn_features = ['score_lesion', 'score_nivel', 'Score_Escalar']
    
    if considerar_precio:
        knn_features.append('Precio')
        df_palas = df_palas[df_palas['Precio'] <= precio_maximo]
    
    knn = NearestNeighbors(n_neighbors=3)
    knn.fit(df_palas[knn_features])
    
    reference_point = [[x_random, y_random, z_random] + ([precio_maximo] if considerar_precio else [])]
    
    distances, indices = knn.kneighbors(reference_point)
    
    palas_recomendadas = df_palas.iloc[indices[0]]
    
    # Mapear valores numéricos a etiquetas descriptivas
    palas_recomendadas["Nivel de Juego"] = palas_recomendadas["Nivel de Juego"].map(LABEL_MAPPING["Nivel de Juego"])
    palas_recomendadas["Tipo de Juego"] = palas_recomendadas["Tipo de Juego"].map(LABEL_MAPPING["Tipo de Juego"])
    palas_recomendadas["Balance"] = palas_recomendadas["Balance"].map(LABEL_MAPPING["Balance"])
    
    return palas_recomendadas[['Palas', 'Nivel de Juego', 'Tipo de Juego', 'Balance', 'Precio']]
    """

# %%
import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import random


df_form3 = pd.read_csv('df_scaled_formularios_3.0.csv')
df_palas3 = pd.read_csv('df_scaled_palas_3.0.csv')

# Seleccionar una fila aleatoria de df_form
random_row = df_form3.sample(1)


# Extraer las coordenadas X e Y de la fila aleatoria
x_random = random_row['Score_Escalar_Lesion']
y_random = random_row['Score_Escalar_Nivel']

# Crear figura
fig = plt.figure(figsize=(20, 14))

# Crear un gráfico en 2D
ax = fig.add_subplot(111)

# Definir los valores de cada eje para el DataFrame principal (df_palas)
x = df_palas3['score_lesion_ajustado']
y = df_palas3['score_nivel_ajustado']
#z = df_palas['Balance']  # Eje Z para df_palas

# Crear el gráfico de dispersión 3D para df_palas
ax.scatter(x, y, color='blue', label='Datos de Palas')

# Crear los puntos adicionales
ax.scatter([x_random], [y_random],
           color='red', s=100, label='Formularios')

# Calcular los límites con buffer
x_min, x_max = x.min(), x.max()
y_min, y_max = y.min(), y.max()
buffer = 0.01  # Cambia este valor para ajustar el tamaño del margen

# Ajustar límites de los ejes con el buffer
ax.set_xlim(x_min - buffer, x_max + buffer)
ax.set_ylim(y_min - buffer, y_max + buffer)

# Añadir etiquetas a los ejes
ax.set_xlabel('Score de Lesión (Escalado)')
ax.set_ylabel('Score de Nivel (Escalado)')

# Título del gráfico
ax.set_title('Gráfico 3D de Score de Lesión, Score de Nivel y Formulario 3 horquillas')

# Añadir leyenda para diferenciar los conjuntos de puntos
ax.legend()

# Mostrar el gráfico
plt.show()

from sklearn.neighbors import NearestNeighbors

# Filtrar filas en base al sexo indicado en df_form
sexo_form = df_form3["Indique su sexo"].iloc[0]  # Supongamos que tomas el sexo de la primera fila de df_form

if sexo_form == "hombre":
    # Filtrar df_palas para incluir solo jugadores "hombre" o "mixta"
    df_palas_filtrado = df_palas3[(df_palas3["Jugador"] == "hombre") | (df_palas3["Jugador"] == "mixta")]
elif sexo_form == "mujer":
    # Filtrar df_palas para incluir solo jugadores "mujer" o "mixta"
    df_palas_filtrado = df_palas3[(df_palas3["Jugador"] == "mujer") | (df_palas3["Jugador"] == "mixta")]
else:
    # En caso de no especificar un sexo, incluir todo el DataFrame
    df_palas_filtrado = df_palas3



label_mapping = {
    "Balance": {"No data": 0, "bajo": 1, "medio": 2, "alto": 3},
    "Nucleo": {"No data": 0, "foam": 1, "medium eva": 2, "hard eva": 3, "soft eva": 4},
    "Cara": {"No data": 0, "fibra de vidrio": 1, "mix": 2, "fibra de carbono": 3},
    "Dureza": {"No data": 0, "blanda": 1, "media": 2, "dura": 3},
    "Nivel de Juego": {"No data": 0, "principiante": 1, "avanzado": 2, "pro": 3},
    "Forma": {"No data": 0, "redonda": 1, "lágrima": 2, "diamante": 3},
    "Superficie": {"No data": 0, "lisa": 1, "rugosa": 2},
    "Tipo de Juego": {"No data": 0, "control": 1, "polivalente": 2, "potencia": 3},
}

def encontrar_vecinos_mas_cercanos_knn_2d(df_palas3, x_random, y_random, considerar_precio, precio_maximo):
    knn_features = ['score_lesion', 'score_nivel']
    
    if considerar_precio:
        knn_features.append('Precio')
        df_palas3 = df_palas3[df_palas3['Precio'] <= precio_maximo]
    
    knn = NearestNeighbors(n_neighbors=3)
    knn.fit(df_palas3[knn_features])
    
    # Crear un punto de referencia con nombres de columnas
    reference_point = pd.DataFrame(
        [[x_random, y_random] + ([precio_maximo] if considerar_precio else [])],
        columns=knn_features
    )
    
    distances, indices = knn.kneighbors(reference_point)
    
    palas_recomendadas = df_palas3.iloc[indices[0]].copy()  # Copiar para evitar problemas de modificación
    

    # Mapear valores numéricos a etiquetas descriptivas
    palas_recomendadas["Nivel de Juego"] = palas_recomendadas["Nivel de Juego"].map(label_mapping["Nivel de Juego"])
    palas_recomendadas["Tipo de Juego"] = palas_recomendadas["Tipo de Juego"].map(label_mapping["Tipo de Juego"])
    palas_recomendadas["Balance"] = palas_recomendadas["Balance"].map(label_mapping["Balance"])
    
    return palas_recomendadas[['Palas', 'Nivel de Juego', 'Tipo de Juego', 'Balance', 'Precio']]


recomendaciones = encontrar_vecinos_mas_cercanos_knn_2d(
    df_palas3=df_palas3, 
    x_random=5, 
    y_random=3, 
    considerar_precio=False, 
    precio_maximo=200
)

# Ver las recomendaciones
if recomendaciones is not None:
    print(recomendaciones)

# %%
recomendaciones = encontrar_vecinos_mas_cercanos_knn_2d(
    df_palas3=df_palas3, 
    x_random=5, 
    y_random=3, 
    considerar_precio=False, 
    precio_maximo=200
)

# Ver las recomendaciones
if recomendaciones is not None:
    print(recomendaciones)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import random

# Verifica las columnas disponibles en df_palas3
print("Columnas en df_palas3:", df_palas3.columns)

# Seleccionar una fila aleatoria de df_form
random_row = df_form3.sample(1)

# Extraer las coordenadas X e Y de la fila aleatoria
x_random = random_row['Score_Escalar_Lesion'].values[0]
y_random = random_row['Score_Escalar_Nivel'].values[0]

# Crear figura
fig = plt.figure(figsize=(20, 14))

# Crear un gráfico en 2D
ax = fig.add_subplot(111)

# Definir los valores de cada eje para el DataFrame principal (df_palas3)
x = df_palas3['score_lesion_ajustado']
y = df_palas3['score_nivel_ajustado']

# Crear el gráfico de dispersión para df_palas3
ax.scatter(x, y, color='blue', label='Datos de Palas')

# Añadir el punto aleatorio del formulario
ax.scatter([x_random], [y_random], color='red', s=100, label='Formulario Aleatorio')

# Llamar a la función para encontrar las palas recomendadas
recomendaciones = encontrar_vecinos_mas_cercanos_knn_2d(
    df_palas3=df_palas3, 
    x_random=x_random, 
    y_random=y_random, 
    considerar_precio=False,  # Cambia a True si deseas filtrar por precio
    precio_maximo=200  # Precio máximo en caso de considerar precio
)

# Si hay recomendaciones, añadirlas al gráfico
if recomendaciones is not None and not recomendaciones.empty:
    for i, row in recomendaciones.iterrows():
        lesion = row.get('score_lesion_ajustado', 0)
        nivel = row.get('score_nivel_ajustado', 0)
        pala = row.get('Palas', 'Desconocida')

        # Añadir puntos de las palas recomendadas
        ax.scatter(lesion, nivel, color='green', s=200, label=f'Recomendada: {pala}')
        
        # Etiquetar cada punto con el nombre de la pala
        ax.text(lesion, nivel, f'{pala}', fontsize=10, color='green')

# Calcular los límites con buffer
x_min, x_max = x.min(), x.max()
y_min, y_max = y.min(), y.max()
buffer = 0.01  # Ajusta este valor para cambiar el margen

# Ajustar límites de los ejes con el buffer
ax.set_xlim(x_min - buffer, x_max + buffer)
ax.set_ylim(y_min - buffer, y_max + buffer)

# Añadir etiquetas a los ejes
ax.set_xlabel('Score de Lesión (Escalado)')
ax.set_ylabel('Score de Nivel (Escalado)')

# Título del gráfico
ax.set_title('Gráfico de Score de Lesión y Nivel con Palas Recomendadas')

# Añadir leyenda para diferenciar los conjuntos de puntos
ax.legend()

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
import pandas as pd
import random

df_form3 = pd.read_csv('df_scaled_formularios_3.0.csv')
df_palas3 = pd.read_csv('df_scaled_palas_3.0.csv')

# Seleccionar una fila aleatoria de df_form
random_row = df_form3.sample(1)

# Extraer las coordenadas X e Y de la fila aleatoria
x_random = random_row['Score_Escalar_Lesion']
y_random = random_row['Score_Escalar_Nivel']

# Crear figura
fig = plt.figure(figsize=(20, 14))

# Crear un gráfico en 2D
ax = fig.add_subplot(111)

# Definir los valores de cada eje para el DataFrame principal (df_palas)
x = df_palas3['score_lesion_ajustado']
y = df_palas3['score_nivel_ajustado']

# Crear el gráfico de dispersión 3D para df_palas
ax.scatter(x, y, color='blue', label='Datos de Palas')

# Crear los puntos adicionales
ax.scatter([x_random], [y_random],
           color='red', s=100, label='Formularios')

# Calcular los límites con buffer
x_min, x_max = x.min(), x.max()
y_min, y_max = y.min(), y.max()
buffer = 0.01  # Cambia este valor para ajustar el tamaño del margen

# Ajustar límites de los ejes con el buffer
ax.set_xlim(x_min - buffer, x_max + buffer)
ax.set_ylim(y_min - buffer, y_max + buffer)

# Añadir etiquetas a los ejes
ax.set_xlabel('Score de Lesión (Escalado)')
ax.set_ylabel('Score de Nivel (Escalado)')

# Título del gráfico
ax.set_title('Gráfico 3D de Score de Lesión, Score de Nivel y Formulario 3 horquillas')

# Añadir leyenda para diferenciar los conjuntos de puntos
ax.legend()

# Mostrar el gráfico
plt.show()

# Función para encontrar vecinos más cercanos
def encontrar_vecinos_mas_cercanos_knn_2d(df_palas3, x_random, y_random, considerar_precio, precio_maximo):
    knn_features = ['score_lesion', 'score_nivel']
    
    if considerar_precio:
        knn_features.append('Precio')
        df_palas3 = df_palas3[df_palas3['Precio'] <= precio_maximo]
    
    knn = NearestNeighbors(n_neighbors=3)
    knn.fit(df_palas3[knn_features])
    
    reference_point = pd.DataFrame(
        [[x_random, y_random] + ([precio_maximo] if considerar_precio else [])],
        columns=knn_features
    )
    
    distances, indices = knn.kneighbors(reference_point)
    
    palas_recomendadas = df_palas3.iloc[indices[0]].copy()

    # Mapear valores numéricos a etiquetas descriptivas
    palas_recomendadas["Nivel de Juego"] = palas_recomendadas["Nivel de Juego"].map(label_mapping["Nivel de Juego"]).fillna("No data")
    palas_recomendadas["Tipo de Juego"] = palas_recomendadas["Tipo de Juego"].map(label_mapping["Tipo de Juego"]).fillna("No data")
    palas_recomendadas["Balance"] = palas_recomendadas["Balance"].map(label_mapping["Balance"]).fillna("No data")
    
    return palas_recomendadas[['Palas', 'Nivel de Juego', 'Tipo de Juego', 'Balance', 'Precio']]

# Parámetros de ejemplo
recomendaciones = encontrar_vecinos_mas_cercanos_knn_2d(
    df_palas3=df_palas3, 
    x_random=5,  # Cambia estos valores según sea necesario
    y_random=3, 
    considerar_precio=False, 
    precio_maximo=200
)

# Ver las recomendaciones
if recomendaciones is not None:
    print(recomendaciones)
