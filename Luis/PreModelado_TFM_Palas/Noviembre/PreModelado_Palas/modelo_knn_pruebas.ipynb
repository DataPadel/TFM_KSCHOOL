# %%
import os 

nueva_ruta = r'C:\Users\Luis\Documents\GitHub\TFM_KSCHOOL\Luis\PreModelado_TFM_Palas\Noviembre\PreModelado_Palas\modelado_streamlit'
os.chdir(nueva_ruta)
print("Nueva ruta actual:", os.getcwd())
# Out:
# Nueva ruta actual: C:\Users\Luis\Documents\GitHub\TFM_KSCHOOL\Luis\PreModelado_TFM_Palas\Noviembre\PreModelado_Palas\modelado_streamlit

# %%
import pandas as pd

df_form = pd.read_csv('df_scaled_formularios.csv')
df_palas = pd.read_csv('df_scaled_palas.csv')

# Verificar la carga
print(df_form.head())
print(df_palas.head())
# Out:
#   Cuantas horas juega a la semana   Indique su peso Indique su sexo  \
# 0              Menos de 3,5 horas  Entre 51 y 70 Kg           Mujer
# 1              Menos de 3,5 horas  Entre 51 y 70 Kg           Mujer
# 2              Menos de 3,5 horas  Entre 51 y 70 Kg           Mujer
# 3              Menos de 3,5 horas  Entre 51 y 70 Kg           Mujer
# 4              Menos de 3,5 horas  Entre 51 y 70 Kg           Mujer
#
#           Indique su altura Rango de precio dispuesto a pagar  \
# 0  Entre 1,51 y 1,70 metros                      Menos de 100
# 1  Entre 1,51 y 1,70 metros                      Menos de 100
# 2  Entre 1,51 y 1,70 metros                      Menos de 100
# 3  Entre 1,51 y 1,70 metros                      Menos de 100
# 4  Entre 1,51 y 1,70 metros                      Menos de 100
#
#   Indique su lado de juego Indique su nivel de juego Tipo de juego  \
# 0                    Drive                Iniciacion      Ofensivo
# 1                    Drive                Iniciacion      Ofensivo
# 2                    Drive                Iniciacion      Ofensivo
# 3                    Drive                Iniciacion      Ofensivo
# 4                    Drive                Iniciacion      Ofensivo
#
#   Que tipo de balance te gusta  \
# 0                        Medio
# 1                        Medio
# 2                        Medio
# 3                        Medio
# 4                        Medio
#
#   Has tenido alguna de las siguientes lesiones previamente lumbares, epicondilitis, gemelos, fascitis, cervicales u hombros  \
# 0                                           Lumbares
# 1                                           Lumbares
# 2                                           Lumbares
# 3                                           Lumbares
# 4                                           Lumbares
#
#                  Con que frecuencia        Hace cuanto  Score_Escalar_Lesion  \
# 0  Siempre que juego defensivamente   Menos de 3 meses              0.694444
# 1  Siempre que juego defensivamente  Entre 3 y 6 meses              0.729167
# 2  Siempre que juego defensivamente     Mas de 6 meses              0.743056
# 3   Siempre que juego ofensivamente   Menos de 3 meses              0.694444
# 4   Siempre que juego ofensivamente  Entre 3 y 6 meses              0.729167
#
#    Score_Escalar_Nivel
# 0             0.111111
# 1             0.111111
# 2             0.111111
# 3             0.111111
# 4             0.111111
#                          Palas  Precio        Marca            Color  Balance  \
# 0              HARLEM EUPHORIA   63.95      No data     negro, verde        0
# 1    VARLION LW DIFUSOR W 2021  149.95      varlion      negro, rosa        1
# 2  DUNLOP BOOST LITE 2.0 WOMAN  109.00  black crown      negro, azul        1
# 3    BLACK CROWN PITON 11 2023   86.95       dunlop             rosa        1
# 4           SIUX FURTIVE PRO 2   62.95         siux  negro, amarillo        2
#
#    Nucleo  Cara  Dureza  Nivel de Juego  Forma  Superficie  Tipo de Juego  \
# 0       4     0       0               2      0           1              0
# 1       4     0       0               2      1           2              0
# 2       2     2       0               2      1           1              1
# 3       4     1       1               1      1           2              1
# 4       4     1       0               2      2           1              0
#
#   Jugador  score_lesion  score_nivel
# 0   mixta      0.346154     0.329068
# 1   mixta      0.480769     0.455210
# 2   mixta      0.476923     0.451554
# 3   mujer      0.603846     0.517367
# 4   mixta      0.584615     0.557587

# %%
import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import random

# Seleccionar una fila aleatoria de df_form
random_row = df_form.sample(200)


# Extraer las coordenadas X e Y de la fila aleatoria
x_random = random_row['Score_Escalar_Lesion']
y_random = random_row['Score_Escalar_Nivel']

# Valores Z fijos para los tres puntos
#z_random = [0, 1, 2]

# Crear figura
fig = plt.figure(figsize=(20, 14))

# Crear un gráfico en 2D
ax = fig.add_subplot(111)

# Definir los valores de cada eje para el DataFrame principal (df_palas)
x = df_palas['score_lesion']
y = df_palas['score_nivel']
#z = df_palas['Balance']  # Eje Z para df_palas

# Crear el gráfico de dispersión 3D para df_palas
ax.scatter(x, y, color='blue', label='Datos de Palas')

# Crear los puntos adicionales
ax.scatter([x_random], [y_random],
           color='red', s=100, label='Formularios')

# Calcular los límites con buffer
x_min, x_max = x.min(), x.max()
y_min, y_max = y.min(), y.max()
buffer = 0.01  # Cambia este valor para ajustar el tamaño del margen

# Ajustar límites de los ejes con el buffer
ax.set_xlim(x_min - buffer, x_max + buffer)
ax.set_ylim(y_min - buffer, y_max + buffer)

# Añadir etiquetas a los ejes
ax.set_xlabel('Score de Lesión (Escalado)')
ax.set_ylabel('Score de Nivel (Escalado)')

# Título del gráfico
ax.set_title('Gráfico 3D de Score de Lesión, Score de Nivel y Formulario 3 horquillas')

# Añadir leyenda para diferenciar los conjuntos de puntos
ax.legend()

# Mostrar el gráfico
plt.show()

# %%
# Filtrar filas en base al sexo indicado en df_form
sexo_form = df_form["Indique su sexo"].iloc[0]  # Supongamos que tomas el sexo de la primera fila de df_form

if sexo_form == "hombre":
    # Filtrar df_palas para incluir solo jugadores "hombre" o "mixta"
    df_palas_filtrado = df_palas[(df_palas["Jugador"] == "hombre") | (df_palas["Jugador"] == "mixta")]
elif sexo_form == "mujer":
    # Filtrar df_palas para incluir solo jugadores "mujer" o "mixta"
    df_palas_filtrado = df_palas[(df_palas["Jugador"] == "mujer") | (df_palas["Jugador"] == "mixta")]
else:
    # En caso de no especificar un sexo, incluir todo el DataFrame
    df_palas_filtrado = df_palas

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np



# Seleccionar 200 filas aleatorias de df_form
random_rows = df_form.sample(200)

# Extraer las coordenadas X e Y de las 200 filas aleatorias
x_random = random_rows['Score_Escalar_Lesion']
y_random = random_rows['Score_Escalar_Nivel']

# Crear figura
fig = plt.figure(figsize=(20, 14))

# Crear un gráfico en 3D
ax = fig.add_subplot(111)

# Definir los valores de cada eje para el DataFrame principal (df_palas_filtrado)
x = df_palas_filtrado['score_lesion']
y = df_palas_filtrado['score_nivel']

# Crear el gráfico de dispersión 3D para df_palas_filtrado
ax.scatter(x, y, color='blue', label='Datos de Palas Filtrados')

# Crear el gráfico de dispersión 3D para los puntos adicionales
ax.scatter(x_random, y_random, color='red', s=100, label='Formulario con 200 propuestas de precios')

# Calcular los límites con buffer
x_min, x_max = x.min(), x.max()
y_min, y_max = y.min(), y.max()
buffer = 0.05  # Cambia este valor para ajustar el tamaño del margen

# Ajustar límites de los ejes con el buffer
ax.set_xlim(x_min - buffer, x_max + buffer)
ax.set_ylim(y_min - buffer, y_max + buffer)

# Añadir etiquetas a los ejes
ax.set_xlabel('Score de Lesión (Escalado)')
ax.set_ylabel('Score de Nivel (Escalado)')

# Título del gráfico
ax.set_title('Gráfico 3D de Score de Lesión, Score de Nivel y Formulario con 200 propuestas')

# Añadir leyenda para diferenciar los conjuntos de puntos
ax.legend()

# Mostrar el gráfico
plt.show()

# %%
from sklearn.neighbors import NearestNeighbors
import pandas as pd
import numpy as np

# Crear los puntos de referencia con sus coordenadas X, Y, Z
reference_points = pd.DataFrame({
    'score_lesion': [x_random] * 3,
    'score_nivel': [y_random] * 3,

})

# Preparar los datos de df_palas para aplicar kNN
# Aseguramos que 'Palas' esté en el DataFrame para poder recuperar los nombres
palas_data = df_palas[['score_lesion', 'score_nivel', 'Balance', 'Palas']].copy()

# Entrenar el modelo kNN con las columnas relevantes (sin la columna 'Palas')
knn = NearestNeighbors(n_neighbors=3)
knn.fit(palas_data[['score_lesion', 'score_nivel', 'Balance']])

# Encontrar los 3 vecinos más cercanos para cada punto de referencia
results = {}
for index, point in reference_points.iterrows():
    distances, indices = knn.kneighbors([point])
    closest_points = palas_data.iloc[indices[0]]
    results[f'Punto {point["Balance"]}'] = closest_points

# Mostrar los resultados con los nombres de las palas
for key, value in results.items():
    print(f"Vecinos más cercanos a {key}:")
    print(value[['Palas', 'score_lesion', 'score_nivel', 'Balance']], "\n")
# Out:
# Vecinos más cercanos a Punto 0.0:
#                                      Palas  score_lesion  score_nivel  Balance
# 469              ENEBE RESPONSE FIBER BLUE      0.680769     0.694698        0
# 696  WINGPADEL AIR COMBAT BLACK ATTACK 4.0      0.634615     0.658135        0
# 546      WINGPADEL AIR TORNADO ATTK 4.0 3K      0.634615     0.658135        0
#
# Vecinos más cercanos a Punto 1.0:
#                                                Palas  score_lesion  \
# 217  ADIDAS CROSS IT LIGHT PRO EDT BY MARTITA ORTEGA      0.692308
# 179             ADIDAS ADIPOWER MULTIWEIGHT CTRL 3.3      0.653846
# 292                        ADIDAS CROSS IT CTRL 2024      0.653846
#
#      score_nivel  Balance
# 217     0.670932        1
# 179     0.597806        1
# 292     0.597806        1
#
# Vecinos más cercanos a Punto 2.0:
#                               Palas  score_lesion  score_nivel  Balance
# 450             STAR VIE ASTRUM PRO      0.711538      0.66362        2
# 250       BLACK CROWN PITON 12 2024      0.711538      0.66362        2
# 349  BLACK CROWN PITON PREMIUM 2024      0.711538      0.66362        2
# C:\Users\Luis\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# C:\Users\Luis\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# C:\Users\Luis\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %%
def encontrar_vecinos_mas_cercanos_knn(df_palas, x_random, y_random, z_random, considerar_precio, precio_maximo):
    knn_features = ['score_lesion', 'score_nivel', 'Score_Escalar']
    
    if considerar_precio:
        knn_features.append('Precio')
        df_palas = df_palas[df_palas['Precio'] <= precio_maximo]
    
    knn = NearestNeighbors(n_neighbors=3)
    knn.fit(df_palas[knn_features])
    
    reference_point = [[x_random, y_random, z_random] + ([precio_maximo] if considerar_precio else [])]
    
    distances, indices = knn.kneighbors(reference_point)
    
    palas_recomendadas = df_palas.iloc[indices[0]]
    
    # Mapear valores numéricos a etiquetas descriptivas
    palas_recomendadas["Nivel de Juego"] = palas_recomendadas["Nivel de Juego"].map(LABEL_MAPPING["Nivel de Juego"])
    palas_recomendadas["Tipo de Juego"] = palas_recomendadas["Tipo de Juego"].map(LABEL_MAPPING["Tipo de Juego"])
    palas_recomendadas["Balance"] = palas_recomendadas["Balance"].map(LABEL_MAPPING["Balance"])
    
    return palas_recomendadas[['Palas', 'Nivel de Juego', 'Tipo de Juego', 'Balance', 'Precio']]

# %%
def encontrar_vecinos_mas_cercanos_knn_2d(df_palas, x_random, y_random, considerar_precio, precio_maximo):
    knn_features = ['score_lesion', 'score_nivel']
    
    if considerar_precio:
        knn_features.append('Precio')
        df_palas = df_palas[df_palas['Precio'] <= precio_maximo]
    
    knn = NearestNeighbors(n_neighbors=3)
    knn.fit(df_palas[knn_features])
    
    reference_point = [[x_random, y_random] + ([precio_maximo] if considerar_precio else [])]
    
    distances, indices = knn.kneighbors(reference_point)
    
    palas_recomendadas = df_palas.iloc[indices[0]]
    
    # Mapear valores numéricos a etiquetas descriptivas
    palas_recomendadas["Nivel de Juego"] = palas_recomendadas["Nivel de Juego"].map(LABEL_MAPPING["Nivel de Juego"])
    palas_recomendadas["Tipo de Juego"] = palas_recomendadas["Tipo de Juego"].map(LABEL_MAPPING["Tipo de Juego"])
    palas_recomendadas["Balance"] = palas_recomendadas["Balance"].map(LABEL_MAPPING["Balance"])
    
    return palas_recomendadas[['Palas', 'Nivel de Juego', 'Tipo de Juego', 'Balance', 'Precio']]
