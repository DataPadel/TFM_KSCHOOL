# %% [markdown]
# EDA CARACTERISTICAS PALAS DE PADEL
#
# El Kernel que he usuado es Python 3.9.19

# %%
import pandas as pd

# %%
palas = pd.read_csv('caracteristicas_palas_padel.csv')

# %%
# %pip install -U ydata-profiling
from ydata_profiling import ProfileReport



profile = ProfileReport(palas, title="Train_EDA_INITIAL.csv")
profile.to_notebook_iframe()
profile.to_file('profile_1 regresion lineal.html')
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-12-15 21:00:47.693125&quot;&gt;&lt;title&gt;Train_EDA_INITIAL.csv&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
# ...
